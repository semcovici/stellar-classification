# %%
import pandas as pd

# %%
raw_data_path = "../data/raw/analysis.csv"

# %%
df = pd.read_csv(raw_data_path)

# %%
df
# Out:
#             obj_ID       alpha      delta         u         g         r  \
# 0     1.237650e+18   48.824760  -8.166999  19.44393  18.43291  18.11620
# 1     1.237658e+18  193.394684  52.336221  22.41654  22.09867  20.53718
# 2     1.237679e+18  324.020999  10.000606  19.49719  17.58264  16.66178
# 3     1.237666e+18  234.965903  23.031949  24.31149  21.99310  20.58364
# 4     1.237665e+18  170.706066  35.630196  25.61850  24.86680  21.37659
# ...            ...         ...        ...       ...       ...       ...
# 9995  1.237658e+18  181.269532  51.273043  18.50853  17.65012  17.27569
# 9996  1.237668e+18  209.743620  19.894152  22.99436  22.08630  20.23164
# 9997  1.237662e+18  177.389727   6.270422  19.52580  17.92479  17.11512
# 9998  1.237668e+18  217.297701  15.970520  21.95136  20.81498  19.93374
# 9999  1.237666e+18  222.865185  19.616170  22.84665  21.87292  20.28989
#
#              i         z  run_ID  rerun_ID  cam_col  field_ID   spec_obj_ID  \
# ...

# %%
# visão geral
print(f"Shape: {df.shape}\n\n")        # (100000, 18)

print("########## DTYPES ##########")
print(df.dtypes)       # tipos de cada coluna

print("\n\n########## VALUE COUNTS ##########")
print(df['class'].value_counts())  # distribuição das classes

print("\n\n########## COUNT NaNs ##########")
print(df.isna().sum())             # contagem de valores faltantes

print("\n\n########## DESCRIBE ##########")
display(df.describe())               # estatísticas descritivas das colunas numéricas
# Out:
# Shape: (10000, 18)
#
#
# ########## DTYPES ##########
# obj_ID         float64
# alpha          float64
# delta          float64
# u              float64
# g              float64
# r              float64
# i              float64
# z              float64
# run_ID           int64
# rerun_ID         int64
# cam_col          int64
# field_ID         int64
# spec_obj_ID    float64
# class           object
# redshift       float64
# plate            int64
# MJD              int64
# fiber_ID         int64
# dtype: object
#
#
# ########## VALUE COUNTS ##########
# class
# GALAXY    5945
# STAR      2159
# QSO       1896
# Name: count, dtype: int64
#
#
# ########## COUNT NaNs ##########
# obj_ID         0
# alpha          0
# delta          0
# u              0
# g              0
# r              0
# i              0
# z              0
# run_ID         0
# rerun_ID       0
# cam_col        0
# field_ID       0
# spec_obj_ID    0
# class          0
# redshift       0
# plate          0
# ...
